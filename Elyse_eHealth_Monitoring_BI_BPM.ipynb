# %% [markdown]
# <a href="https://colab.research.google.com/github/Epvargas/Elyse-Data-Science-Analytics-Research/blob/main/Elyse_eHealth_Monitoring_BI_BPM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**eHealth Monitoring in a Naonatal Intenseive Care Unit (NICU)**

# %% [markdown]
# ![2021-04-19 (40).png](data:image/png;base64,...)

# %% [markdown]
# ## Project Life Cycle

# %% [markdown]
# ![2021-04-19 (41).png](data:image/png;base64,...)

# %% [markdown]
# ## Business Process "As-It" at NICU

# %% [markdown]
# ![2021-04-19 (42).png](data:image/png;base64,...)

# %% [markdown]
# ## Process "As-Tobe" at NICU

# %% [markdown]
# ![2021-04-19 (43).png](data:image/png;base64,...)

# %% [markdown]
# ## New Patients Creation (on a Mobil Device)

# %% [markdown]
# ![2021-04-19 (44).png](data:image/png;base64,...)

# %% [markdown]
# ## Patient Information: Electronic Healthcare Record (EHR)

# %% [markdown]
# ![2021-04-19 (45).png](data:image/png;base64,...)

# %% [markdown]
# ## Nursing Monitoring using EHR

# %% [markdown]
# ![2021-04-19 (46).png](data:image/png;base64,...)

# %% [markdown]
# ## Medical Evaluation (EHR)

# %% [markdown]
# ![2021-04-19 (47).png](data:image/png;base64,...)

# %% [markdown]
# ## Performance Indicators and Dashboard of the NICU Solution

# %% [markdown]
# ![2021-04-19 (51).png](data:image/png;base64,...)

# %% [markdown]
# On-Premise infrastructure of the NICU Platform

# %% [markdown]
# ![2021-04-19 (48).png](data:image/png;base64,...)
